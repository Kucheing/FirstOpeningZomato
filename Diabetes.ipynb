# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler, StandardScaler
import seaborn as sns
import matplotlib.pyplot as plt

#preparing the environment with libraries like pandas, numpy, scikit learn, matplotlib and seaborn
#for data manipulation numerical operations, visualization and scaling

# %%
df = pd.read_csv('C:Users/ASUS/ZD-1201DataAnalytics/Imports/diabetes.csv')
df.head()

#

# %%
df.info()
print(df.isnull().sum())
